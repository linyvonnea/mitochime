# %%
import pandas as pd
from joblib import load
from mitochime.hyperparam_search_top import load_dataset  # or reuse your helper

X_test, y_test, feature_names = load_dataset("../data/processed/test_noq.tsv")

models = {
    "catboost_tuned":        load("../models_noq_tuned/catboost_tuned.joblib"),
    "gradient_boosting_tuned": load("../models_noq_tuned/gradient_boosting_tuned.joblib"),
    "bagging_trees_tuned":   load("../models_noq_tuned/bagging_trees_tuned.joblib"),
    "logreg_l2_base":        load("../models_noq/logreg_l2.joblib"),  # not tuned
}

# %%
from sklearn.inspection import permutation_importance
import numpy as np
from pathlib import Path

feat_dir = Path("../reports/feature_importance")
feat_dir.mkdir(parents=True, exist_ok=True)  # make sure folder exists

def perm_importance(model, X, y, feature_names, scoring="f1", n_repeats=10):
    result = permutation_importance(
        model, X, y,
        n_repeats=n_repeats,
        random_state=42,
        n_jobs=-1,
        scoring=scoring,
    )
    df = pd.DataFrame({
        "feature": feature_names,
        "importance_mean": result.importances_mean,
        "importance_std": result.importances_std,
    }).sort_values("importance_mean", ascending=False)
    return df

imp_results = {}

for name, model in models.items():
    print(f"\n=== Permutation importance ({name}) ===")
    df_imp = perm_importance(model, X_test, y_test, feature_names, scoring="f1")
    imp_results[name] = df_imp

    # save
    df_imp.to_csv(feat_dir / f"perm_imp_{name}.tsv",
                  sep="\t", index=False)

    print(df_imp.head(10))
# Out:
# === Permutation importance (catboost_tuned) ===
#                  feature  importance_mean  importance_std
# 17   total_clipped_bases         0.082066        0.002651
# 20    kmer_js_divergence         0.076510        0.003378
# 19      kmer_cosine_diff         0.058167        0.002891
# 15         softclip_left         0.026290        0.002867
# 16        softclip_right         0.025894        0.002075
# 1                   mapq         0.006059        0.000839
# 22      microhomology_gc         0.000528        0.000842
# 21  microhomology_length         0.000340        0.000659
# 6       sa_min_delta_pos         0.000057        0.000748
# 13             sa_min_nm         0.000000        0.000000
#
# === Permutation importance (gradient_boosting_tuned) ===
#                  feature  importance_mean  importance_std
# 17   total_clipped_bases         0.118542        0.002420
# 20    kmer_js_divergence         0.061129        0.002969
# 19      kmer_cosine_diff         0.044505        0.002501
# 15         softclip_left         0.014654        0.001491
# 1                   mapq         0.006149        0.000909
# 16        softclip_right         0.004905        0.000609
# 21  microhomology_length         0.000283        0.000799
# 0            read_length         0.000000        0.000000
# 18   breakpoint_read_pos         0.000000        0.000000
# 14            sa_mean_nm         0.000000        0.000000
#
# === Permutation importance (bagging_trees_tuned) ===
#                  feature  importance_mean  importance_std
# 17   total_clipped_bases         0.309329        0.003839
# 20    kmer_js_divergence         0.026443        0.002373
# 19      kmer_cosine_diff         0.012592        0.001619
# 1                   mapq         0.004151        0.000681
# 21  microhomology_length         0.001005        0.001212
# 16        softclip_right         0.000105        0.001002
# 7       sa_max_delta_pos         0.000090        0.000141
# 0            read_length         0.000000        0.000000
# 14            sa_mean_nm         0.000000        0.000000
# 5         sa_diff_contig         0.000000        0.000000
#
# === Permutation importance (logreg_l2_base) ===
# /Users/yvonnelin/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 27
#      25 for name, model in models.items():
#      26     print(f"\n=== Permutation importance ({name}) ===")
# ---> 27     df_imp = perm_importance(model, X_test, y_test, feature_names, scoring="f1")
#      28     imp_results[name] = df_imp
#      30     # save
#
# Cell In[5], line 9, in perm_importance(model, X, y, feature_names, scoring, n_repeats)
#       8 def perm_importance(model, X, y, feature_names, scoring="f1", n_repeats=10):
# ----> 9     result = permutation_importance(
#      10         model, X, y,
#      11         n_repeats=n_repeats,
#      12         random_state=42,
#      13         n_jobs=-1,
#      14         scoring=scoring,
#      15     )
#      16     df = pd.DataFrame({
#      17         "feature": feature_names,
#      18         "importance_mean": result.importances_mean,
#      19         "importance_std": result.importances_std,
#      20     }).sort_values("importance_mean", ascending=False)
#      21     return df
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/inspection/_permutation_importance.py:282, in permutation_importance(estimator, X, y, scoring, n_repeats, n_jobs, random_state, sample_weight, max_samples)
#     279     raise ValueError("max_samples must be <= n_samples")
#     281 scorer = check_scoring(estimator, scoring=scoring)
# --> 282 baseline_score = _weights_scorer(scorer, estimator, X, y, sample_weight)
#     284 scores = Parallel(n_jobs=n_jobs)(
#     285     delayed(_calculate_permutation_scores)(
#     286         estimator,
#    (...)    296     for col_idx in range(X.shape[1])
#     297 )
#     299 if isinstance(baseline_score, dict):
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/inspection/_permutation_importance.py:25, in _weights_scorer(scorer, estimator, X, y, sample_weight)
#      23 if sample_weight is not None:
#      24     return scorer(estimator, X, y, sample_weight=sample_weight)
# ---> 25 return scorer(estimator, X, y)
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:279, in _BaseScorer.__call__(self, estimator, X, y_true, sample_weight, **kwargs)
#     276 if sample_weight is not None:
#     277     _kwargs["sample_weight"] = sample_weight
# --> 279 return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:371, in _Scorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     369 pos_label = None if is_regressor(estimator) else self._get_pos_label()
#     370 response_method = _check_response_method(estimator, self._response_method)
# --> 371 y_pred = method_caller(
#     372     estimator, response_method.__name__, X, pos_label=pos_label
#     373 )
#     375 scoring_kwargs = {**self._kwargs, **kwargs}
#     376 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:89, in _cached_call(cache, estimator, response_method, *args, **kwargs)
#      86 if cache is not None and response_method in cache:
#      87     return cache[response_method]
# ---> 89 result, _ = _get_response_values(
#      90     estimator, *args, response_method=response_method, **kwargs
#      91 )
#      93 if cache is not None:
#      94     cache[response_method] = result
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/utils/_response.py:211, in _get_response_values(estimator, X, response_method, pos_label, return_response_method_used)
#     208     elif pos_label is None and target_type == "binary":
#     209         pos_label = classes[-1]
# --> 211 y_pred = prediction_method(X)
#     213 if prediction_method.__name__ in ("predict_proba", "predict_log_proba"):
#     214     y_pred = _process_predict_proba(
#     215         y_pred=y_pred,
#     216         target_type=target_type,
#     217         classes=classes,
#     218         pos_label=pos_label,
#     219     )
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/pipeline.py:600, in Pipeline.predict(self, X, **params)
#     598 if not _routing_enabled():
#     599     for _, name, transform in self._iter(with_final=False):
# --> 600         Xt = transform.transform(Xt)
#     601     return self.steps[-1][1].predict(Xt, **params)
#     603 # metadata routing enabled
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/impute/_base.py:570, in SimpleImputer.transform(self, X)
#     555 """Impute all missing values in `X`.
#     556
#     557 Parameters
#    (...)    566     `X` with imputed values.
#     567 """
#     568 check_is_fitted(self)
# --> 570 X = self._validate_input(X, in_fit=False)
#     571 statistics = self.statistics_
#     573 if X.shape[1] != statistics.shape[0]:
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/impute/_base.py:350, in SimpleImputer._validate_input(self, X, in_fit)
#     348         raise new_ve from None
#     349     else:
# --> 350         raise ve
#     352 if in_fit:
#     353     # Use the dtype seen in `fit` for non-`fit` conversion
#     354     self._fit_dtype = X.dtype
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/impute/_base.py:332, in SimpleImputer._validate_input(self, X, in_fit)
#     329     force_all_finite = True
#     331 try:
# --> 332     X = self._validate_data(
#     333         X,
#     334         reset=in_fit,
#     335         accept_sparse="csc",
#     336         dtype=dtype,
#     337         force_writeable=True if not in_fit else None,
#     338         force_all_finite=force_all_finite,
#     339         copy=self.copy,
#     340     )
#     341 except ValueError as ve:
#     342     if "could not convert" in str(ve):
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~/miniconda3/envs/mitochime/lib/python3.11/site-packages/sklearn/base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 23 features, but SimpleImputer is expecting 24 features as input.
