# %%
import pandas as pd

df = pd.read_csv("../data/all_features_merged.tsv", sep="\t")
df.shape
df.head()

df["label"].value_counts()
df.describe()
# Out:
#               label  read_length  mean_base_quality  ref_start_1based  \
# count  39983.000000      39983.0       39983.000000      39983.000000
# mean       0.500213        150.0          26.505740       8314.426356
# std        0.500006          0.0          13.500168       4443.001528
# min        0.000000        150.0          13.000000          3.000000
# 25%        0.000000        150.0          13.000000       4653.000000
# 50%        1.000000        150.0          40.000000       8340.000000
# 75%        1.000000        150.0          40.000000      11955.500000
# max        1.000000        150.0          40.000000      16516.000000
#
#                mapq        has_sa      sa_count  num_segments  sa_diff_contig  \
# count  39983.000000  39983.000000  39983.000000  39983.000000         39983.0
# mean      59.825301      0.203011      0.203011      1.203011             0.0
# std        1.469844      0.402246      0.402246      0.402246             0.0
# ...
